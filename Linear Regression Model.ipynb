# %% [markdown]
# ## Optional Lab: Model Representation
# ### Goals
# In this lab you will:
# - Learn to implement the model $f_{b_0, b_1} = b_0 + b_1x$ for linear regression with one variabl
# ### Tools
# In this lab you will use of:
# - Numpy, apopular library for scientific computing
# - Matplotlib, a popular for plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1, 2])
y_train = np.array([300, 500])
print(f'x_train = {x_train}')
print(f'y_train = {y_train}')
print(f'x_train shape is {x_train.shape}')
print(f'The number of training sample is: {x_train.shape[0]}')
# Out:
# x_train = [1 2]
# y_train = [300 500]
# x_train shape is (2,)
# The number of training sample is: 2

# %%
plt.scatter(x_train, y_train, marker='x', c = 'r')
plt.title('Housing Prices')
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
b0 = 100
b1 = 100
def model(x, b0, b1):
    m = x.shape[0]
    reg = np.zeros(m)
    for i in range(m):
        reg[i] = b0 + b1*x[i]
    return reg

# %%
result = model(x_train, b0, b1)
plt.plot(x_train, result, c = 'b', label = 'Our Prediction')
plt.scatter(x_train, y_train, marker = 'x', c = 'r', label = 'Actual Values')
plt.title("Housing Prices")
plt.legend()
plt.show()

# %%
result = model(x_train, b0 = 100, b1 = 200)
plt.plot(x_train, result, c = 'b', label = 'Our Prediction')
plt.scatter(x_train, y_train, marker = 'x', c = 'r', label = 'Actual Values')
plt.title("Housing Prices")
plt.legend()
plt.show()
